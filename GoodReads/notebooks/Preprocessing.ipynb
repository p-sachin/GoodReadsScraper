# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re
from sklearn.preprocessing import MinMaxScaler
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from collections import OrderedDict
# %matplotlib inline

# %%
dataframe = pd.read_csv('goodread_final_data.csv')

# %%
dataframe
# Out:
#                                                     url  \
# 0     http://www.goodreads.com/book/show/136251.Harr...
# 1     http://www.goodreads.com/book/show/2767052-the...
# 2     http://www.goodreads.com/book/show/1.Harry_Pot...
# 3     http://www.goodreads.com/book/show/6.Harry_Pot...
# 4     http://www.goodreads.com/book/show/2.Harry_Pot...
# ...                                                 ...
# 6394  http://www.goodreads.com/book/show/4820815-rac...
# 6395  http://www.goodreads.com/book/show/32706309-ea...
# 6396  http://www.goodreads.com/book/show/145342.How_...
# 6397  http://www.goodreads.com/book/show/470175.The_...
# 6398     http://www.goodreads.com/book/show/296912.Pyro
#
#                                           title              author  \
# 0          Harry Potter and the Deathly Hallows        J.K. Rowling
# 1                              The Hunger Games     Suzanne Collins
# 2        Harry Potter and the Half-Blood Prince        J.K. Rowling
# 3           Harry Potter and the Goblet of Fire        J.K. Rowling
# 4     Harry Potter and the Order of the Phoenix        J.K. Rowling
# ...                                         ...                 ...
# 6394                                       None                None
# 6395                             East End Tales       Gilda O'Neill
# 6396    How to Be a Girly Girl in Just Ten Days  Lisa Papademetriou
# 6397                 The Ransom of Mercy Carter  Caroline B. Cooney
# 6398                                       Pyro        Earl Emerson
#
#      num_reviews num_ratings avg_rating  num_pages original_publish_year  \
# 0          71115     3093559       4.61      759.0                  2007
# 1         179564     6998314       4.32      284.0                  2008
# 2          44399     2697998       4.57      652.0                  2005
# 3          52560     2888017       4.56      734.0                  2000
# 4          48162     2782996       4.50      870.0                  2003
# ...          ...         ...        ...        ...                   ...
# 6394        None        None       None        NaN                  None
# 6395          22          93       3.51       50.0                  2002
# 6396         132        2948       4.05      163.0                  2007
# 6397         180        1933       3.80      256.0                  2000
# 6398          20         203       3.84      320.0                  2004
#
#       series                                             genres  \
# 0       True              ['Fantasy', 'Young Adult', 'Fiction']
# 1       True      ['Young Adult', 'Fiction', 'Science Fiction']
# 2       True              ['Fantasy', 'Young Adult', 'Fiction']
# 3       True              ['Fantasy', 'Young Adult', 'Fiction']
# 4       True              ['Fantasy', 'Young Adult', 'Fiction']
# ...      ...                                                ...
# 6394   False                                                 []
# 6395   False                                     ['Nonfiction']
# 6396    True         ['Childrens', 'Childrens', 'Middle Grade']
# 6397   False  ['Historical', 'Historical Fiction', 'Young Ad...
# 6398   False                 ['Mystery', 'Thriller', 'Fiction']
#
#                                                  awards  \
# 0     ['Locus Award Nominee for Best Young Adult Nov...
# 1     ['Locus Award Nominee for Best Young Adult Boo...
# 2     ['Locus Award Nominee for Best Young Adult Nov...
# 3     ['Hugo Award for Best Novel (2001)', " Mythopo...
# 4     ['Bram Stoker Award for Works for Young Reader...
# ...                                                 ...
# 6394                                               None
# 6395                                                NaN
# 6396                                                NaN
# 6397                                                NaN
# 6398                                                NaN
#
#                                                  places
# 0     ['London, England', 'Hogwarts School of Witchc...
# 1     ['District 12, Panem', 'Capitol, Panem', 'Panem']
# 2     ['Hogwarts School of Witchcraft and Wizardry',...
# 3     ['Hogwarts School of Witchcraft and Wizardry',...
# 4     ['Hogwarts School of Witchcraft and Wizardry',...
# ...                                                 ...
# 6394                                                 []
# 6395                                                 []
# 6396                                                 []
# 6397  ['Canada', 'Deerfield, Massachusetts', 'Massac...
# 6398                                                 []
#
# [6399 rows x 12 columns]

# %%
dataframe['awards'] = dataframe.awards.fillna(0)

# %%
is_NaN = dataframe.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = dataframe[row_has_NaN]
# dataframe = dataframe.dropna()

# %%
rows_with_NaN.to_csv('NaN-Values.csv', index=False)

# %%
is_NaN = dataframe.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = dataframe[row_has_NaN]
# dataframe = dataframe.dropna()

# %%
rows_with_NaN
# Out:
# Empty DataFrame
# Columns: [url, title, author, num_reviews, num_ratings, avg_rating, num_pages, original_publish_year, series, genres, awards, places]
# Index: []

# %%
dataframe["awards"] = dataframe.loc[dataframe['awards'] != 0, 'awards'].apply(eval).str.len()
# Out:
# C:\Users\Ellefson\miniconda3\envs\strive-ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataframe
# Out:
#                                                     url  \
# 0     http://www.goodreads.com/book/show/136251.Harr...
# 1     http://www.goodreads.com/book/show/2767052-the...
# 2     http://www.goodreads.com/book/show/1.Harry_Pot...
# 3     http://www.goodreads.com/book/show/6.Harry_Pot...
# 4     http://www.goodreads.com/book/show/2.Harry_Pot...
# ...                                                 ...
# 6393  http://www.goodreads.com/book/show/6738284-the...
# 6395  http://www.goodreads.com/book/show/32706309-ea...
# 6396  http://www.goodreads.com/book/show/145342.How_...
# 6397  http://www.goodreads.com/book/show/470175.The_...
# 6398     http://www.goodreads.com/book/show/296912.Pyro
#
#                                                   title              author  \
# 0                  Harry Potter and the Deathly Hallows        J.K. Rowling
# 1                                      The Hunger Games     Suzanne Collins
# 2                Harry Potter and the Half-Blood Prince        J.K. Rowling
# 3                   Harry Potter and the Goblet of Fire        J.K. Rowling
# 4             Harry Potter and the Order of the Phoenix        J.K. Rowling
# ...                                                 ...                 ...
# 6393  The Language of Life: DNA and the Revolution i...  Francis S. Collins
# 6395                                     East End Tales       Gilda O'Neill
# 6396            How to Be a Girly Girl in Just Ten Days  Lisa Papademetriou
# 6397                         The Ransom of Mercy Carter  Caroline B. Cooney
# 6398                                               Pyro        Earl Emerson
#
#      num_reviews num_ratings avg_rating  num_pages original_publish_year  \
# 0          71115     3093559       4.61      759.0                  2007
# 1         179564     6998314       4.32      284.0                  2008
# 2          44399     2697998       4.57      652.0                  2005
# 3          52560     2888017       4.56      734.0                  2000
# 4          48162     2782996       4.50      870.0                  2003
# ...          ...         ...        ...        ...                   ...
# 6393          69         637       3.99      368.0                  2009
# 6395          22          93       3.51       50.0                  2002
# 6396         132        2948       4.05      163.0                  2007
# 6397         180        1933       3.80      256.0                  2000
# 6398          20         203       3.84      320.0                  2004
#
#       series                                             genres  awards  \
# 0       True              ['Fantasy', 'Young Adult', 'Fiction']     8.0
# 1       True      ['Young Adult', 'Fiction', 'Science Fiction']    41.0
# 2       True              ['Fantasy', 'Young Adult', 'Fiction']     3.0
# 3       True              ['Fantasy', 'Young Adult', 'Fiction']     9.0
# 4       True              ['Fantasy', 'Young Adult', 'Fiction']     9.0
# ...      ...                                                ...     ...
# 6393   False               ['Science', 'Nonfiction', 'Biology']     NaN
# 6395   False                                     ['Nonfiction']     NaN
# 6396    True         ['Childrens', 'Childrens', 'Middle Grade']     NaN
# 6397   False  ['Historical', 'Historical Fiction', 'Young Ad...     NaN
# 6398   False                 ['Mystery', 'Thriller', 'Fiction']     NaN
#
#                                                  places
# 0     ['London, England', 'Hogwarts School of Witchc...
# 1     ['District 12, Panem', 'Capitol, Panem', 'Panem']
# 2     ['Hogwarts School of Witchcraft and Wizardry',...
# 3     ['Hogwarts School of Witchcraft and Wizardry',...
# 4     ['Hogwarts School of Witchcraft and Wizardry',...
# ...                                                 ...
# 6393                                                 []
# 6395                                                 []
# 6396                                                 []
# 6397  ['Canada', 'Deerfield, Massachusetts', 'Massac...
# 6398                                                 []
#
# [5596 rows x 12 columns]

# %%
dataframe['awards'] = dataframe.awards.fillna(0)
# Out:
# C:\Users\Ellefson\miniconda3\envs\strive-ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataframe["awards"] = dataframe["awards"].astype(int)
# Out:
# C:\Users\Ellefson\miniconda3\envs\strive-ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataframe
# Out:
#                                                     url  \
# 0     http://www.goodreads.com/book/show/136251.Harr...
# 1     http://www.goodreads.com/book/show/2767052-the...
# 2     http://www.goodreads.com/book/show/1.Harry_Pot...
# 3     http://www.goodreads.com/book/show/6.Harry_Pot...
# 4     http://www.goodreads.com/book/show/2.Harry_Pot...
# ...                                                 ...
# 6393  http://www.goodreads.com/book/show/6738284-the...
# 6395  http://www.goodreads.com/book/show/32706309-ea...
# 6396  http://www.goodreads.com/book/show/145342.How_...
# 6397  http://www.goodreads.com/book/show/470175.The_...
# 6398     http://www.goodreads.com/book/show/296912.Pyro
#
#                                                   title              author  \
# 0                  Harry Potter and the Deathly Hallows        J.K. Rowling
# 1                                      The Hunger Games     Suzanne Collins
# 2                Harry Potter and the Half-Blood Prince        J.K. Rowling
# 3                   Harry Potter and the Goblet of Fire        J.K. Rowling
# 4             Harry Potter and the Order of the Phoenix        J.K. Rowling
# ...                                                 ...                 ...
# 6393  The Language of Life: DNA and the Revolution i...  Francis S. Collins
# 6395                                     East End Tales       Gilda O'Neill
# 6396            How to Be a Girly Girl in Just Ten Days  Lisa Papademetriou
# 6397                         The Ransom of Mercy Carter  Caroline B. Cooney
# 6398                                               Pyro        Earl Emerson
#
#      num_reviews num_ratings avg_rating  num_pages original_publish_year  \
# 0          71115     3093559       4.61      759.0                  2007
# 1         179564     6998314       4.32      284.0                  2008
# 2          44399     2697998       4.57      652.0                  2005
# 3          52560     2888017       4.56      734.0                  2000
# 4          48162     2782996       4.50      870.0                  2003
# ...          ...         ...        ...        ...                   ...
# 6393          69         637       3.99      368.0                  2009
# 6395          22          93       3.51       50.0                  2002
# 6396         132        2948       4.05      163.0                  2007
# 6397         180        1933       3.80      256.0                  2000
# 6398          20         203       3.84      320.0                  2004
#
#       series                                             genres  awards  \
# 0       True              ['Fantasy', 'Young Adult', 'Fiction']       8
# 1       True      ['Young Adult', 'Fiction', 'Science Fiction']      41
# 2       True              ['Fantasy', 'Young Adult', 'Fiction']       3
# 3       True              ['Fantasy', 'Young Adult', 'Fiction']       9
# 4       True              ['Fantasy', 'Young Adult', 'Fiction']       9
# ...      ...                                                ...     ...
# 6393   False               ['Science', 'Nonfiction', 'Biology']       0
# 6395   False                                     ['Nonfiction']       0
# 6396    True         ['Childrens', 'Childrens', 'Middle Grade']       0
# 6397   False  ['Historical', 'Historical Fiction', 'Young Ad...       0
# 6398   False                 ['Mystery', 'Thriller', 'Fiction']       0
#
#                                                  places
# 0     ['London, England', 'Hogwarts School of Witchc...
# 1     ['District 12, Panem', 'Capitol, Panem', 'Panem']
# 2     ['Hogwarts School of Witchcraft and Wizardry',...
# 3     ['Hogwarts School of Witchcraft and Wizardry',...
# 4     ['Hogwarts School of Witchcraft and Wizardry',...
# ...                                                 ...
# 6393                                                 []
# 6395                                                 []
# 6396                                                 []
# 6397  ['Canada', 'Deerfield, Massachusetts', 'Massac...
# 6398                                                 []
#
# [5596 rows x 12 columns]

# %%
dataframe.to_csv('goodread_final_5596.csv', index=False)
